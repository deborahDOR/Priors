# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.axes as ax
from astropy.coordinates import SkyCoord
import astropy.units as u
import pandas as pd
import math

# %%
alpha=0.25
Rb=0.8
Rd=2.5
Zd=0.4

R_Gal=15


#Galactic distribution
def P_pos(long, lat):
   
    P=[]
    
    for l in long:
        for b in lat:
            
            coord_gal=SkyCoord(l*u.rad, b*u.rad,frame="icrs",distance=R_Gal)
            gc_icrs = coord_gal.transform_to('galactic')
            gc_l_rad,gc_b_rad=gc_icrs.l.radian,gc_icrs.b.radian
            coord_gal=SkyCoord(gc_l_rad*u.rad, gc_b_rad*u.rad,frame="galactic",distance=R_Gal)
            coord_galc=coord_gal.cartesian
            xgc,ygc,zgc=pd.Series(np.array([(coord_galc.x),(coord_galc.y),(coord_galc.z)]))
            c = SkyCoord(x=xgc, y=ygc, z=zgc, representation_type='cartesian')
            x,y,z=pd.Series(np.array([(c.x),(c.y),(c.z)]))
            
            
            r_sq=x**2+y**2+z**2
            u_sq=x**2+y**2

            P.append((alpha*np.exp(-r_sq/Rb**2)+(1-alpha)*np.exp(-np.sqrt(u_sq)/Rd)*(1/np.cosh((z/Zd))**2)))       
    
    P_f=[]
    P_norm=[]
    P_tot = []
   
    for i in range(len(P)):
        P_norm.append((P[i]-np.amin(P))/(np.amax(P)-np.amin(P)))
        P_f.append((1-0.1)*P_norm[i]+0.1)

    for i in range(N):
        P_tot.append([])

    for i in range(N):
        P_tot[i]=P_f[0+N*i:(i+1)*N]
        
    return P_tot

# %%
alpha=0.25
Rb=0.8
Rd=2.5
Zd=0.4


#Ecliptic distribution
import astropy.coordinates as coord

R_Gal=15
Dist_Sun=7.2
def P_pos_bis(long, lat):
   
    P=[]
    
    
    for l in long:
        for b in lat:
            
            c=SkyCoord(l*u.rad, b*u.rad,frame="icrs",distance=15*u.kpc)
            c_gal=c.transform_to(coord.Galactocentric(galcen_distance=8*u.kpc))
            c_gal_set=coord.SkyCoord(c_gal.x,c_gal.y,c_gal.z,frame=coord.Galactocentric)
            c_ecl=c_gal_set.transform_to("barycentricmeanecliptic")
            c_eclp_cart=c_ecl.cartesian
            xec,yec,zec=c_eclp_cart.x.value,c_eclp_cart.y.value,c_eclp_cart.z.value
            
            r_sq=xec**2+yec**2+zec**2
            u_sq=xec**2+yec**2
    
            P.append((alpha*np.exp(-r_sq/Rb**2)+(1-alpha)*np.exp(-np.sqrt(u_sq)/Rd)*(1/np.cosh((zec/Zd))**2)))       
    
    P_f=[]
    P_norm=[]
    P_tot = []
   
    for i in range(len(P)):
        P_norm.append((P[i]-np.amin(P))/(np.amax(P)-np.amin(P)))
        P_f.append((1-0.1)*P_norm[i]+0.1)

    for i in range(N):
        P_tot.append([])

    for i in range(N):
        P_tot[i]=P_f[0+N*i:(i+1)*N]
        
    return P_tot

# %%
c=SkyCoord(-np.pi*u.rad, -np.pi/2*u.rad,frame="icrs",distance=15*u.kpc)
c_gal=c.transform_to(coord.Galactocentric(galcen_distance=8*u.kpc))
c_gal_set=coord.SkyCoord(c_gal.x,c_gal.y,c_gal.z,frame=coord.Galactocentric)
c_ecl=c_gal_set.transform_to("barycentricmeanecliptic")
c_eclp_cart=c_ecl.cartesian
xec,yec,zec=c_eclp_cart.x.value,c_eclp_cart.y.value,c_eclp_cart.z.value

print(c_gal_set)
print(xec)
# Out:
# <SkyCoord (Galactocentric: galcen_coord=<ICRS Coordinate: (ra, dec) in deg
#     (266.4051, -28.936175)>, galcen_distance=8.122 kpc, galcen_v_sun=(12.9, 245.6, 7.78) km / s, z_sun=20.8 pc, roll=0.0 deg): (x, y, z) in kpc
#     (-0.7602554, -11.20472946, -6.83780972)>
# -0.006706334419686603

# %%
print(np.shape(P_pos(tab_l,tab_b)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(np.shape(P_pos(tab_l,tab_b)))
#
# NameError: name 'tab_l' is not defined

# %%
N=100
tab_l_deg=np.linspace(-180,180,N)
tab_b_deg=np.linspace(-90,90,N)

tab_l_rad=np.linspace(-np.pi,np.pi,N)
tab_b_rad=np.linspace(-np.pi/2,np.pi/2,N)

# %%
l, b = np.meshgrid(np.radians(tab_l_deg),np.radians(tab_b_deg))

plt.figure()
ax = plt.subplot(111, projection='mollweide')
plt.pcolormesh(l, b, P_pos(tab_l_rad,tab_b_rad))


plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[61], line 5
#       3 plt.figure()
#       4 ax = plt.subplot(111, projection='mollweide')
# ----> 5 plt.pcolormesh(l, b, P_pos(tab_l_rad,tab_b_rad))
#       8 plt.show()
#
# Cell In[41], line 17, in P_pos(long, lat)
#      14 for l in long:
#      15     for b in lat:
# ---> 17         coord_gal=SkyCoord(l*u.rad, b*u.rad,frame="icrs",distance=R_Gal)
#      18         gc_icrs = coord_gal.transform_to('galactic')
#      19         gc_l_rad,gc_b_rad=gc_icrs.l.radian,gc_icrs.b.radian
#
# File ~/Documents/lisaenv/lib/python3.9/site-packages/astropy/coordinates/sky_coordinate.py:356, in SkyCoord.__init__(self, copy, *args, **kwargs)
#     354 # Finally make the internal coordinate object.
#     355 frame_kwargs.update(components)
# --> 356 self._sky_coord_frame = frame_cls(copy=copy, **frame_kwargs)
#     358 if not self._sky_coord_frame.has_data:
#     359     raise ValueError("Cannot create a SkyCoord without data")
#
# File ~/Documents/lisaenv/lib/python3.9/site-packages/astropy/coordinates/baseframe.py:317, in BaseCoordinateFrame.__init__(self, copy, representation_type, differential_type, *args, **kwargs)
#     312 self._attr_names_with_defaults = []
#     314 self._representation = self._infer_representation(
#     315     representation_type, differential_type
#     316 )
# --> 317 self._data = self._infer_data(args, copy, kwargs)  # possibly None.
#     319 # Set frame attributes, if any
#     321 values = {}
#
# File ~/Documents/lisaenv/lib/python3.9/site-packages/astropy/coordinates/baseframe.py:475, in BaseCoordinateFrame._infer_data(self, args, copy, kwargs)
#     472     representation_cls = representation_cls._unit_representation
#     474 try:
# --> 475     representation_data = representation_cls(copy=copy, **repr_kwargs)
#     476 except TypeError as e:
#     477     # this except clause is here to make the names of the
#     478     # attributes more human-readable.  Without this the names
#     479     # come from the representation instead of the frame's
#     480     # attribute names.
#     481     try:
#
# File ~/Documents/lisaenv/lib/python3.9/site-packages/astropy/coordinates/representation.py:2011, in SphericalRepresentation.__init__(self, lon, lat, distance, differentials, copy)
#    2010 def __init__(self, lon, lat=None, distance=None, differentials=None, copy=True):
# -> 2011     super().__init__(lon, lat, distance, copy=copy, differentials=differentials)
#    2012     if (
#    2013         not isinstance(self._distance, Distance)
#    2014         and self._distance.unit.physical_type == "length"
#    2015     ):
#    2016         try:
#
# File ~/Documents/lisaenv/lib/python3.9/site-packages/astropy/coordinates/representation.py:710, in BaseRepresentation.__init__(self, differentials, *args, **kwargs)
#     708 def __init__(self, *args, differentials=None, **kwargs):
#     709     # Handle any differentials passed in.
# --> 710     super().__init__(*args, **kwargs)
#     711     if differentials is None and args and isinstance(args[0], self.__class__):
#     712         differentials = args[0]._differentials
#
# File ~/Documents/lisaenv/lib/python3.9/site-packages/astropy/coordinates/representation.py:253, in BaseRepresentationOrDifferential.__init__(self, *args, **kwargs)
#     250         raise TypeError(f"unexpected keyword arguments: {kwargs}")
#     252 # Pass attributes through the required initializing classes.
# --> 253 attrs = [
#     254     self.attr_classes[component](attr, copy=copy, subok=True)
#     255     for component, attr in zip(components, attrs)
#     256 ]
#     257 try:
#     258     bc_attrs = np.broadcast_arrays(*attrs, subok=True)
#
# File ~/Documents/lisaenv/lib/python3.9/site-packages/astropy/coordinates/representation.py:254, in <listcomp>(.0)
#     250         raise TypeError(f"unexpected keyword arguments: {kwargs}")
#     252 # Pass attributes through the required initializing classes.
#     253 attrs = [
# --> 254     self.attr_classes[component](attr, copy=copy, subok=True)
#     255     for component, attr in zip(components, attrs)
#     256 ]
#     257 try:
#     258     bc_attrs = np.broadcast_arrays(*attrs, subok=True)
#
# File ~/Documents/lisaenv/lib/python3.9/site-packages/astropy/coordinates/angles.py:541, in Latitude.__new__(cls, angle, unit, **kwargs)
#     539 if isinstance(angle, Longitude):
#     540     raise TypeError("A Latitude angle cannot be created from a Longitude angle")
# --> 541 self = super().__new__(cls, angle, unit=unit, **kwargs)
#     542 self._validate_angles()
#     543 return self
#
# File ~/Documents/lisaenv/lib/python3.9/site-packages/astropy/coordinates/angles.py:142, in Angle.__new__(cls, angle, unit, dtype, copy, **kwargs)
#     137     elif isiterable(angle) and not (
#     138         isinstance(angle, np.ndarray) and angle.dtype.kind not in "SUVO"
#     139     ):
#     140         angle = [Angle(x, unit, copy=False) for x in angle]
# --> 142 return super().__new__(cls, angle, unit, dtype=dtype, copy=copy, **kwargs)
#
# File ~/Documents/lisaenv/lib/python3.9/site-packages/astropy/units/quantity.py:466, in Quantity.__new__(cls, value, unit, dtype, copy, order, subok, ndmin)
#     463     if float_default and value.dtype.kind in "iu":
#     464         dtype = float
# --> 466     return np.array(
#     467         value, dtype=dtype, copy=copy, order=order, subok=True, ndmin=ndmin
#     468     )
#     470 # Maybe str, or list/tuple of Quantity? If so, this may set value_unit.
#     471 # To ensure array remains fast, we short-circuit it.
#     472 value_unit = None
#
# File ~/Documents/lisaenv/lib/python3.9/site-packages/astropy/units/quantity.py:605, in Quantity.__array_finalize__(self, obj)
#     600         self._set_unit(unit)
#     602 # Copy info if the original had `info` defined.  Because of the way the
#     603 # DataInfo works, `'info' in obj.__dict__` is False until the
#     604 # `info` attribute is accessed or set.
# --> 605 if "info" in obj.__dict__:
#     606     self.info = obj.info
#
# KeyboardInterrupt:

# %%
l, b = np.meshgrid(np.radians(tab_l_deg), np.radians(tab_b_deg))

plt.figure()
ax = plt.subplot(111, projection='mollweide')
plt.pcolormesh(l, b, P_pos_bis(tab_l_rad,tab_b_rad))

plt.show()

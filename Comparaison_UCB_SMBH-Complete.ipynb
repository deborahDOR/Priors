# %%
import ldc.waveform.fastGB as FB
from ldc.lisa import orbits
from astropy import units as un
import numpy as np
#from memory_profiler import profile
import fastGB as FB_MLDC
import matplotlib.pyplot as plt
import math

# %%
#SourceParameters

#def chi_f(alpha_f,m):
#        return (4*alpha_f*m)/(4*alpha_f*m+m)
    
def func_h0(M,alpha,chi,chi_f):
    return(8e-28/10)*(M)*(alpha/0.1)**7*((chi-chi_f)/0.1)

def func_freq(M,alpha):
    return (645)*(10/M)*(alpha/0.1)

def func_fdot(M,alpha,chi):
    return 3e-14*(10**2/M)**2*(alpha/0.1)**19*chi**2

def param(M,alpha,chi,chi_f):
    tab=[]
    h0=func_h0(M,alpha,chi,chi_f)
    
    long=np.random.uniform(-np.pi,np.pi)
    lat=np.random.uniform(-np.pi/2,np.pi/2)
    
    f=func_freq(M,alpha)
    fdot=func_fdot(M,alpha,chi)
    
    inc=np.arccos(np.random.uniform(-1,1))
    initialPhase=np.random.uniform(0,2*np.pi)
    pol=np.random.uniform(0,2*np.pi)
    
    tab=(h0,long,lat,f,fdot,inc,initialPhase,pol)
    return tab


tab_Param=param(M=10**6,alpha=0.12,chi=0.5,chi_f=0.45)
print(tab_Param)
# Out:
# (1.4332723199999993e-22, 1.5580098932707553, 1.212385613881843, 0.00774, 2.3960999952796703e-21, 2.62864441500803, 3.0222158913013857, 1.4319463132920047)

# %%
import numpy as np
import matplotlib.pyplot as plt
from ldc.lisa.orbits import Orbits
from ldc.waveform.waveform import HpHc
from ldc.lisa.projection import ProjectedStrain
import ldc.io.yml as ymlio
import os
import h5py
import ldc.waveform.fastGB as FB
from ldc.common.series import TimeSeries
from ldc.common import constants

config = {"dt":15.0, "initial_position": 0, "initial_rotation": 0, 
          "nominal_arm_length": 2500000000, "orbit_type": 'analytic', 
          "t_max": 60*60*24*30*6, "t_min": 0, "travel_time_order": 1}


cat = np.array([tab_Param],
               dtype=[('Amplitude', '<f8'),
                      ('EclipticLatitude', '<f8'),
                      ('EclipticLongitude', '<f8'),
                      ('Frequency', '<f8'), ('FrequencyDerivative', '<f8'),
                      ('Inclination', '<f8'), ('InitialPhase', '<f8'),
                      ('Polarization', '<f8')])

GB = HpHc.type("GB", "GB", "TD_fdot")
GB.set_param(cat)
GWs = GB.split()

globals().update(config)
trange = np.arange(t_min, t_max, dt)
orbits = Orbits.type(config)
P = ProjectedStrain(orbits)
yArm = P.arm_response(t_min, t_max, dt, GWs, tt_order=travel_time_order)

simple_tdi_X = P.compute_tdi_x(trange, tdi2=False)
simple_tdi_X = TimeSeries(simple_tdi_X,dt=dt,t0=t_min)
simple_tdi_X = simple_tdi_X.ts.fft()

simple_tdi2_X = P.compute_tdi_x(trange, tdi2=True)
simple_tdi2_X = TimeSeries(simple_tdi2_X, dt=dt,t0=t_min)
simple_tdi2_X = simple_tdi2_X.ts.fft()

GB = FB.FastGB(delta_t=dt, T=t_max)
pGB = dict(zip(cat.dtype.names, cat[0]))
X, Y, Z = GB.get_fd_tdixyz(template=pGB)
X2, Y2, Z2 = GB.get_fd_tdixyz(template=pGB, tdi2=True)

plt.figure()
plt.title("real part")
plt.plot(simple_tdi2_X.f, simple_tdi2_X.real, alpha=0.5, label="simple TDI X2")
plt.plot(X2.f, X2.real, alpha=0.5, label="fastGB",linestyle='dashed')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.axis([pGB["Frequency"]-1e-6, pGB["Frequency"]+3e-6, None, None])
plt.xlim([0.0077385,0.0077415])
plt.legend()
plt.figure()
plt.title("imaginary part")
plt.plot(simple_tdi2_X.f, simple_tdi2_X.imag, alpha=0.5, label="simple TDI X2")
plt.plot(X2.f, X2.imag, alpha=0.5, label="fastGB",linestyle='dashed')
plt.axis([pGB["Frequency"]-1e-6, pGB["Frequency"]+3e-6, None, None])
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.xlim([0.0077385,0.0077415])
plt.legend()

# %%
X2_t,Y2_t,Z2_t=GB.get_td_tdixyz(template=pGB,oversample=4,tdi2=True)
print(dt)
# Out:
# 15.0

# %%
print(dt)
print(t_max/dt)
print(len(X2_t))
# Out:
# 15.0
# 1036800.0
# 1036799

# %%
plt.plot(X2_t.t, X2_t, alpha=0.5, label="fastGB",linestyle='dashed')
#plt.axis(1/[pGB["Frequency"]-1e-6, 1/pGB["Frequency"]+3e-6, None, None])
print(len(X2_t))
# Out:
# 1036799

# %%
N=len(X2_t)
Tobs = 365*24*60*60*0.5
T=Tobs
dt=T/N

t= np.arange(0, Tobs,T/N)
plt.plot(t,X2_t)
print(dt)
print(len(t))
plt.figure()
plt.plot(X2_t[:-1036700])
# Out:
# 15.20834800187886
# 1036799

# %%
import ldc
from ldc.lisa.noise import get_noise_model
from ldc.lisa.noise import NumericNoise
AddLDC = True

import backgroundsmaster
from backgroundsmaster.backgrounds.utils import generate_noise
generate_noise

f_sampling=1/dt
#get_noise_model("SciRDv1",f).psd(option='X',tdi2=True)
N=len(X2_t)

c=299792458.0
L_m = 2.5e9
L = L_m/c
#omegaL = 2*np.pi*f*L
f1=0.4e-3
def Sn_X2(f):
    S_I=5.76e-48*(1+(f1/f)**2)
    S_II=3.6e-41
    return (4*np.pi*f*L)**2*(np.sin(np.pi*f*L))**2*(2*np.sin(2*np.pi*f*L))**2*((S_I/(2*np.pi*f)**4)+S_II)

tab_noise_t=generate_noise(psd_func=Sn_X2, n_data=N, fs=f_sampling)

# %%
c=299792458.0
L_m = 2.5e9
L = L_m/c

## Noise level in the Science Requirement Document
sqSnoise_SciRD = [3e-15,15e-12]

## Noise level in the Science Requirement Document
sqSnoise_MRD = [2.4e-15,10e-12]

def PSD_Noise_components(fr, sqSnoise):
    [sqSacc_level, sqSoms_level] = sqSnoise
    # sqSacc_level: Amplitude level of acceleration noise [3e-15]
    # sqSoms_level: Amplitude level of OMS noise [15e-12]
    
    
    ### Acceleration noise
    Sa_a = sqSacc_level**2 *(1.0 +(0.4e-3/fr)**2)*(1.0+(fr/8e-3)**4)
    Sa_d = Sa_a*(2.*np.pi*fr)**(-4.)
    Sa_nu = Sa_d*(2.0*np.pi*fr/c)**2

    ### Optical Metrology System
    Soms_d = sqSoms_level**2 * (1. + (2.e-3/fr)**4)
    Soms_nu = Soms_d*(2.0*np.pi*fr/c)**2
    
    return [Sa_nu, Soms_nu]

def PSD_Noise_X20(f):
    [Sa_nu,Soms_nu] = [3e-15,15e-12]
    phiL = 2*np.pi*f*L
    return 64 * (np.sin(phiL))**2 * ( np.sin(2*phiL))**2 * (Soms_nu + Sa_nu*(3+np.cos(2*phiL)) )

# %%
noise_t=generate_noise(psd_func=PSD_Noise_X20, n_data=N, fs=f_sampling)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 noise_t=generate_noise(psd_func=PSD_Noise_X20, n_data=N, fs=f_sampling)
#
# NameError: name 'generate_noise' is not defined

# %%
print(tab_noise_t)
plt.plot(tab_noise_t)
# Out:
# [-2.89183657e-21  2.98600878e-21 -2.37289885e-21 ...  4.75028326e-22
#  -1.40035393e-21  1.73340783e-21]

# %%
def Pd_num(x,dt):
    #window=np.blackman(len(x))
    window=1
    #N_w=np.sum(window**2)
    N_w=len(x)
    return dt*(2/N_w)*(np.abs(np.fft.rfft(window*x)))**2

def FT_norm(x,dt):
    #window=np.blackman(len(x))
    window=1
    #N_w=np.sum(window**2)
    N_w=len(x)
    return dt*(2/N_w)*(np.abs(np.fft.rfft(window*x)))

f= np.fft.rfftfreq(int(N),d=dt)
plt.figure()
plt.loglog(f,Pd_num(tab_noise_t,dt))
plt.xlim([5e-5,3e-2])
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.loglog(f,FT_norm(tab_noise_t,dt))
plt.subplot(1,2,2)
plt.loglog(f,np.sqrt(dt*(2/N))*np.sqrt(Pd_num(tab_noise_t,dt)))
print(len(FT_norm(tab_noise_t,dt)))

factor=np.sqrt(dt*(2/N))
plt.figure()
PSD_sciRD_X2usb=get_noise_model("SciRDv1",f[1:]).psd(option='X',tdi2=True)
plt.loglog(f[1:],factor*np.sqrt(PSD_sciRD_X2usb))
plt.xlim([5e-5,3e-2])
# Out:
# 518400
# (5e-05, 0.03)

# %%
N=len(X2_t)
print(dt)
def Pd_num(x,dt):
    #window=np.blackman(len(x))
    window=1
    N_w=np.sum(window**2)
    N_w=len(x)
    return dt*(2/N_w)*(np.abs(np.fft.rfft(window*x)))**2


f= np.fft.rfftfreq(int(N),d=dt)
plt.loglog(f,Pd_num(X2_t,dt))
plt.xlim([5e-5,3e-2])
plt.figure()
plt.loglog(f,FT_norm(X2_t,dt))
# Out:
# 15.20834800187886

# %%
h=FT_norm(X2_t,dt)
n=FT_norm(tab_noise_t,dt)
d=h+n
plt.loglog(f,d)
plt.ylim([1*10**(-25),(10**(-21))])
plt.xlim([pGB["Frequency"]-1e-3, pGB["Frequency"]+0.75e-3])
plt.xlim(7.5825e-3, 7.685e-3)
plt.ylabel('Amplitude')
plt.xlabel('Frequency (Hz)')
# Out:
# Text(0.5, 0, 'Frequency (Hz)')

# %%
print(cat)
# Out:
# [(1.43327232e-22, 1.55800989, 1.21238561, 0.00774, 2.3961e-21, 2.62864442, 3.02221589, 1.43194631)]

# %%
pos_1=[]
pos_2=[]
def position(freq,tf):
    for f,i in zip (freq,range(len(tf))):
        if f>=7.5825e-3:
            pos_1.append(i)
            p1=pos_1[0]
        if f<=7.685e-3:
            pos_2.append(i)
            p2=pos_2[-1]
    return p1,p2

p1,p2=position(f,n)
print(p1)
print(p2)
print("Size of new window :",p2-p1)

f_n=f[p1:p2]
d_n=d[p1:p2]

plt.loglog(f_n,d_n)
# Out:
# 119561
# 121177
# Size of new window : 1616

# %%
def loglikelihood(d,h,Sn):
    return -np.sum(np.abs(d_n-h_n)**2/Sn_n)

# %%
def par2dic(par):
    """
    Transforms parameter array into a dictionnary.

    Parameters
    ----------
    par : ndarray
        waveform parameters:
        Amplitude
        Ecliptic latitude
        Ecliptic longitude
        Frequency
        Frequency derivative
        Inclination
        Initial phase
        Polarization

    """
    pgb = dict({'Amplitude': par[0],# "strain"
              'EclipticLatitude': par[1], # "radian"
              'EclipticLongitude': par[2],# "radian"
              'Frequency': par[3], #"Hz"
              'FrequencyDerivative': par[4],# "Hz^2"
              'Inclination': par[5],# "radian"
              'InitialPhase': par[6], #"radian"
              'Polarization': par[7]}) #"radian"

    return pgb


def waveform2sample(par):
    """
    Tramsform waveform parameters into a format suitable for sampling

    Parameters
    ----------
    par : ndarray
        waveform parameters
        # Amplitude
        # Ecliptic latitude
        # Ecliptic longitude
        # Frequency
        # Frequency derivative
        # Inclination
        # Initial phase
        # Polarization

    Returns
    -------
    psample : ndarray
        log10(amplitude), frequency in mHz, log10(frequency derivative)
        sin(Latitude), Longitude, cos(inclination), polarization, Initial phase

    """

    Amp, bet, lam, f0, fdot, iota, phi0, psi = par
    sin_b = np.sin(bet)
    cos_i = np.cos(iota)
    l_Amp = np.log10(Amp)
    l_fdot = np.log10(fdot)

    p_sample = np.array([l_Amp, f0*1.e3, l_fdot, sin_b, lam, cos_i, psi, phi0])

    return p_sample


def waveform_from_samplepar(pars, freqs=None):
    """

    Compute the waveform in X, Y, Z from sampling parameters


    Parameters
    ----------
    pars : ndarray
        log10(amplitude),
        frequency in mHz,
        log10(frequency derivatite)
        sin(Latitude),
        Longitude,
        cos(inclination),
        polarization,
        Initial phase


    Returns
    -------
    Xf, Yf, Zf : FrequencyArrays
        Waveform in the frequency domain in TDI X, Y, Z [second]

    """
    pp = pars[:]
    l_Amp = pp[0]
    mf0 = pp[1]
    l_fdot = pp[2]
    sin_bet = pp[3]
    lam = pp[4]
    cos_iota = pp[5]
    psi = pp[6]
    phi0 = pp[7]

    # Transform sampling parameters into waveform parameters
    iota = np.arccos(cos_iota)
    beta = np.arcsin(sin_bet)
    Amp = 10.0**l_Amp
    f0 = mf0 *1.e-3
    fdot = 10.0**l_fdot

    pgb = dict({'Amplitude': Amp,# "strain"
              'EclipticLatitude': beta, # "radian"
              'EclipticLongitude': lam,# "radian"
              'Frequency': f0, #"Hz"
              'FrequencyDerivative': fdot,# "Hz^2"
              'Inclination': iota,# "radian"
              'InitialPhase': phi0, #"radian"
              'Polarization': psi}) #"radian"

    Xf, Yf, Zf = GB.get_fd_tdixyz(
        template=pgb, oversample=4, tdi2=True, freqs=freqs)

    return Xf, Yf, Zf


def loglike(pars, dataf, id):
    """
    Log-likelihood

    Parameters
    ----------
    pars : ndarray
        array of sampling parameters :
        log10(amplitude)
        frequency (mHz)
        log10(frequencyDerivative)
        sinus(beta) : sinus of latitude
        lambda : longitude
        cos(i) : cosinus of inclination
        psi : polarization angle [rad]
        phi0 : initial phase [rad]
    dataf : ndarray
        full data in the frequency domain
    id : ndarray
        indices of the frequency bins to consider

    Returns
    -------
    loglik : float
        likelihood value

    """

    #freqs = dataf.f[id]
    freqs=f_n
    Xf, Yf, Zf = waveform_from_samplepar(pars, freqs=freqs)

    df = 1/GB.T
    # # Index of the first data frequency
    # ib = int(freqs[0] / df)
    # # Index of the last data frequency
    # ie = int(freqs[-1] / df)

    f0 = pars[1]*1e-3
    #Sn = noise_model.psd(freq=f0, option='X', tdi2=True)
    Sn=get_noise_model("SciRDv1",f0).psd(option='X',tdi2=True)

    # Xf = Xf/df
    #SNR2 = np.sum( np.real(dataf[id] * np.conjugate(Xf)) )
    SNR2 = np.sum( np.real(d_n * np.conjugate(Xf)) )
    hh = np.sum(np.absolute(Xf)**2)
    loglik = 4.0*df*( SNR2 - 0.5 * hh )/Sn

    return float(loglik)

# %%
# Varying the log-amplitude
nvalues = 100
prange = np.linspace(a[0], b[0], nvalues)
dps = prange - p_sample_true[0]
l_vect = np.zeros(nvalues)
s_vect = np.zeros(nvalues)
ps = copy.deepcopy(p_sample_true)
# plt.figure(0)
for i in range(nvalues):
    ps[0] = prange[i]
    l_vect[i] = loglike(ps, tdi_fs_noisy['X'], id)
# Likelihood at true parameter value
l_true = loglike(p_sample_true, tdi_fs_noisy['X'], id)

plt.figure(0)
plt.plot(dps, l_vect)
plt.xlabel("Log-amplitude deviation")
plt.ylabel("Log-likelihood")
plt.vlines(x=0.0, ymin=np.min(l_vect), ymax=l_true,
           label='True value', color='red', linestyle='dotted')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[126], line 11
#       9 for i in range(nvalues):
#      10     ps[0] = prange[i]
# ---> 11     l_vect[i] = loglike(ps, tdi_fs_noisy['X'], id)
#      12 # Likelihood at true parameter value
#      13 l_true = loglike(p_sample_true, tdi_fs_noisy['X'], id)
#
# NameError: name 'tdi_fs_noisy' is not defined

# %%
id=np.arange(p1,p2)
print(len(id))
# Out:
# 1616

# %%
print(len(cat))
print(cat[0])
print(type(cat[0]))
cat_a=np.array(cat[0])
print(type(cat_a))
#print(len(cat_a))
param_array=np.array([1.43327232e-22, 2.12578338, 0.25878119, 0.00774, 2.3961e-21, 1.81178354, 0.62268665, 5.94923749])
print(len(param_array))
# Out:
# 1
# (1.43327232e-22, 1.55800989, 1.21238561, 0.00774, 2.3961e-21, 2.62864442, 3.02221589, 1.43194631)
# <class 'numpy.void'>
# <class 'numpy.ndarray'>
# 8

# %%
#t1_param=par2dic(param_array)
t2_param=waveform2sample(param_array)
print(t2_param)
# Out:
# [-21.84367129   7.74       -20.62049506   0.84990726   0.25878119
#   -0.23866143   5.94923749   0.62268665]

# %%
p_sample_true = waveform2sample(param_array)

# %%
# Lower bounds
#p0[0]=param_array[0]
#p0[1]=param_array[3]
a = np.array([t2_param[0] - 1, t2_param[1] - 1e-3, -24.0, -1.0, -np.pi, -1.0, 0.0, 0.0])
# Upper bounds
b = np.array([t2_param[0] + 1, t2_param[1] + 1e-3, -18.0, 1.0, np.pi, 1.0, 2.0*np.pi, 2.0*np.pi])

# %%
import copy
from ldc.lisa import noise

nvalues = 100
prange = np.linspace(a[0], b[0], nvalues)
dps = prange - p_sample_true[0]
l_vect = np.zeros(nvalues)
s_vect = np.zeros(nvalues)
ps = copy.deepcopy(p_sample_true)
# plt.figure(0)
for i in range(nvalues):
    ps[0] = prange[i]
    l_vect[i] = loglike(ps, n, id)
# Likelihood at true parameter value
l_true = loglike(p_sample_true, n, id)

plt.figure(0)
plt.plot(dps, l_vect)
plt.xlabel("Log-amplitude deviation")
plt.ylabel("Log-likelihood")
plt.vlines(x=0.0, ymin=np.min(l_vect), ymax=l_true,
           label='True value', color='red', linestyle='dotted')
plt.show()

# %%
#sampler 
#priors
from scipy.special import gamma

Phi_s=10**(-3)
logMass_s=8.4
M_star=10**logMass_s
a=-1.19
beta2=0.5116394637708428

def Dist_BH(M,d):
    #M=(645*10*alpha_moy)/(f*0.1)
    return (1/(d+1))**(beta2)*Phi_s*(M/M_star)**(1+a)*np.exp(1-(M/M_star))

def Dist_Mass1(M):
    #M=(645*10*alpha_moy)/(f*0.1)
    return Phi_s*(M/(M_star))**(1+a)*np.exp(1-(M/M_star))

def Dist_Mass2(M):
    #M=(645*10*alpha_moy)/(f*0.1)
    return Phi_s*(M/(M_star))**(1+a)*np.exp(1-(M/M_star))



#frequency
alpha_moy=0.12
alpha=alpha_moy
C1=(645*10*alpha_moy)/0.1
def P_f0(f):
    f=f*1e-3
    #if (10**4 < f < 10**2):
    #p=((1/C1)*Dist_Mass1((f/C1))
    p=((1/C1)*Dist_Mass1((f/C1)**(-1)))
    #else :
        #p=0
    return p

#frequency derivative
chi=0.5
C2=3e14*10**2*(alpha/0.1)**19*chi**2
def P_f0dot(f):
    f=10**f
    #p=((2*f)/C2)*Dist_Mass1((f**2/C2))
    return ((2*f)/C2)*Dist_Mass1((np.sqrt((f**2/C2))**(-1)))

#Amplitudeh_0
m=1
def chi_f(alpha_f):
    return (4*alpha_f*m)/(4*alpha_f*m+m)
    
def dist_z(z):
    return Phi_s*(z/M_star)**(beta2-2)*np.exp(1)*gamma(a-beta2+1)


C3=(8e-28/10)*(alpha/0.1)**7*(10**6)*((chi-0.45)/0.1)
def P_h0(x):
    x=10**x
    #if (1e-25 < x < 1e-18):
    #p=
    #else :
        #p=0
    return ((1/(C3))*dist_z(x/C3))

#Position
def P_lat(sinbeta):
    beta=np.arcsin(sinbeta)
    if ((beta>=-np.pi/2) & (beta <=np.pi/2)):
        P_beta=1/np.pi
    else :
        P_beta=0
    return P_beta
    
def P_long(lamb):
       
    if ((lamb>=-np.pi) & (lamb <=np.pi)):
            P_lamb=1/(2*np.pi)
    else :
        P_lamb=0
        
    return P_lamb

def P_cos_inc(x):
    if ((x>=-1) & (x <=1)):
            p=1/2
    else :
        p=0
        
    return p


def P_Pol(x):
    if ((x>=-np.pi) & (x <=np.pi)):
            p=1/(2*np.pi)
    else :
        p=0
        
    return p

def P_Phase(x):
    if ((x>=-np.pi) & (x <=np.pi)):
            p=1/(2*np.pi)
    else :
        p=0
        
    return p
    

#Theta=(h0,f,fdot,(beta,lamb))

# %%
def logprior_set(theta,a,b):
    logh0,f,logfdot,sinbeta,lamb,cos_i,pol,ph=theta
    if (a[0] <= logh0) and (b[0] >= logh0):
        p0=np.log(P_h0(logh0))
    else : 
        p0=-np.inf
    if (a[1] <= f) and (b[1] >= f):
        p1=np.log(P_f0(f))
    else : 
        p1=-np.inf
    if (a[2] <= logfdot) and (b[2] >= logfdot):
        p2=np.log(P_f0dot(f))
    else : 
        p2=-np.inf
    if (a[3] <= sinbeta) and (b[3] >= sinbeta):
        p3=np.log(1/np.pi)
    else : 
        p3=-np.inf
    if (a[4] <= lamb) and (b[4] >= lamb):
        p4=np.log(1/2*np.pi)
    else : 
        p4=-np.inf
    if (a[5] <= cos_i) and (b[5] >= cos_i):
        p5=np.log(1/2)
    else : 
        p5=-np.inf
    if (a[6] <= pol) and (b[6] >= pol):
        p6=np.log(1/(2*np.pi))
    else : 
        p6=-np.inf
    if (a[7] <= ph) and (b[7] >= ph):
        p7=np.log(1/(2*np.pi))
    else : 
        p7=-np.inf
    #if np.all(a <= theta) and np.all(b >= theta):
        #return np.log(P_h0(logh0)*P_f0(f)*P_f0dot(f)*P_lat(sinbeta)*P_long(lamb)*P_cos_inc(cos_i)*
                      #P_Pol(pol)*P_Phase(ph))
    return p0+p1+p2+p3+p4+p5+p6+p7

# %%
print ((1/(C3))*(dist_z(10**(-22)/C3)))
print(P_h0(-21))
print(P_f0(7))
print(Dist_Mass1(10**7))
# Out:
# [-1.05702292e+11  8.23768601e+35  2.47687035e+09 -3.65217219e+32
#  -9.24200428e+31 -3.65217219e+32  1.86859542e+32  1.86859542e+32]
# [-3.43339576e+09  2.67574485e+34  8.04530918e+07 -1.18628956e+31
#  -3.00196503e+30 -1.18628956e+31  6.06952554e+30  6.06952554e+30]
# [1.03545508e+45 8.94205367e-28 5.49356937e+47 3.49656647e-07
#  3.89044069e-02 3.49656647e-07 1.53916333e-09 1.53916333e-09]
# [9.95737144e+27 1.52196585e-15 4.14004353e+29 2.61219087e-03
#  2.60156465e+00 2.61219087e-03 1.03993192e-04 1.03993192e-04]

# %%
def logprior_set(theta,a,b):
    logh0,f,logfdot,sinbeta,lamb,cos_i,pol,ph=theta
    if np.all(a <= theta) and np.all(b >= theta):
        p=np.log((P_h0(logh0))*P_f0(f)*P_f0dot(f)*P_lat(sinbeta)*P_long(lamb)*P_cos_inc(cos_i)*
                      P_Pol(pol)*P_Phase(ph))
    else :
        p=-inf
    return p

# %%
# Lower bounds
a = np.array([t2_param[0] - 1, t2_param[1] - 1e-3, -24.0, -1.0, -np.pi, -1.0, 0.0, 0.0])
# Upper bounds
b = np.array([t2_param[0] + 1, t2_param[1] + 1e-3, -18.0, 1.0, np.pi, 1.0, 2.0*np.pi, 2.0*np.pi])

# %%
print(param_array)
print(t2_param)
# Out:
# [1.43327232e-22 2.12578338e+00 2.58781190e-01 7.74000000e-03
#  2.39610000e-21 1.81178354e+00 6.22686650e-01 5.94923749e+00]
# [-21.84367129   7.74       -20.62049506   0.84990726   0.25878119
#   -0.23866143   5.94923749   0.62268665]

# %%
import corner
import ptemcee
from PTMCMCSampler import PTMCMCSampler

ndim = len(t2_param)
nwalkers = 8 * ndim
ntemps = 20
nit = 4000
thin = 1
nsave = 1000
nverbose = 10

# Instantiate the sampler
sampler = ptemcee.Sampler(nwalkers, ndim, loglike,
                              logprior_set, ntemps=int(ntemps),
                              loglargs=[d_n,id],
                              logpargs=[a,b],
                              pool=None)
# Intialize the parameter state
pos = np.random.uniform(low=a,high=b,size=(ntemps, nwalkers, ndim))
#print (pos[0])

# %%
# Run the sampler (long!)
result = sampler.run_mcmc(p0=pos, iterations=nit, thin=thin)
chaindata = sampler.chain[:]
# Out:
# /tmp/ipykernel_1583549/3792320270.py:4: RuntimeWarning: invalid value encountered in log
#   p=np.log((P_h0(logh0))*P_f0(f)*P_f0dot(f)*P_lat(sinbeta)*P_long(lamb)*P_cos_inc(cos_i)*
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 2
#       1 # Run the sampler (long!)
# ----> 2 result = sampler.run_mcmc(p0=pos, iterations=nit, thin=thin)
#       3 chaindata = sampler.chain[:]
#
# File ~/Documents/lisaenv/lib/python3.9/site-packages/ptemcee/sampler.py:277, in Sampler.run_mcmc(self, *args, **kwargs)
#     272 def run_mcmc(self, *args, **kwargs):
#     273     """
#     274     Identical to ``sample``, but returns the final ensemble and discards intermediate ensembles.
#     275
#     276     """
# --> 277     for x in self.sample(*args, **kwargs):
#     278         pass
#     279     return x
#
# File ~/Documents/lisaenv/lib/python3.9/site-packages/ptemcee/sampler.py:345, in Sampler.sample(self, p0, iterations, thin, storechain, adapt, swap_ratios)
#     343 # If we have no likelihood or prior values, compute them.
#     344 if self._logposterior0 is None or self._loglikelihood0 is None:
# --> 345     logl, logp = self._evaluate(p)
#     346     logpost = self._tempered_likelihood(logl) + logp
#     348     self._loglikelihood0 = logl
#
# File ~/Documents/lisaenv/lib/python3.9/site-packages/ptemcee/sampler.py:430, in Sampler._evaluate(self, ps)
#     428 def _evaluate(self, ps):
#     429     mapf = map if self.pool is None else self.pool.map
# --> 430     results = list(mapf(self._likeprior, ps.reshape((-1, self.dim))))
#     432     logl = np.fromiter((r[0] for r in results), np.float64,
#     433                        count=len(results)).reshape((self.ntemps, -1))
#     434     logp = np.fromiter((r[1] for r in results), np.float64,
#     435                        count=len(results)).reshape((self.ntemps, -1))
#
# File ~/Documents/lisaenv/lib/python3.9/site-packages/ptemcee/sampler.py:130, in LikePriorEvaluator.__call__(self, x)
#     128 def __call__(self, x):
#     129     lp = self.logp(x, *self.logpargs, **self.logpkwargs)
# --> 130     if np.isnan(lp):
#     131         raise ValueError('Prior function returned NaN.')
#     133     if lp == float('-inf'):
#     134         # Can't return -inf, since this messes with beta=0 behaviour.
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
def loglikelihood(x):
    return np.sum(np.abs(d_n[x]-h_n[x])**2/PSD_sciRD_X2usb[x])

# %%
x=[10**(-23),10**(-22),10**(-22)]
plt.plot(P_h0())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 plt.plot(P_h0)
#
# File ~/Documents/lisaenv/lib/python3.9/site-packages/matplotlib/pyplot.py:2748, in plot(scalex, scaley, data, *args, **kwargs)
#    2746 @_copy_docstring_and_deprecators(Axes.plot)
#    2747 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2748     return gca().plot(
#    2749         *args, scalex=scalex, scaley=scaley,
#    2750         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/Documents/lisaenv/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1670, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1668 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1669 for line in lines:
# -> 1670     self.add_line(line)
#    1671 if scalex:
#    1672     self._request_autoscale_view("x")
#
# File ~/Documents/lisaenv/lib/python3.9/site-packages/matplotlib/axes/_base.py:2333, in _AxesBase.add_line(self, line)
#    2330 if line.get_clip_path() is None:
#    2331     line.set_clip_path(self.patch)
# -> 2333 self._update_line_limits(line)
#    2334 if not line.get_label():
#    2335     line.set_label(f'_child{len(self._children)}')
#
# File ~/Documents/lisaenv/lib/python3.9/site-packages/matplotlib/axes/_base.py:2356, in _AxesBase._update_line_limits(self, line)
#    2352 def _update_line_limits(self, line):
#    2353     """
#    2354     Figures out the data limit of the given line, updating self.dataLim.
#    2355     """
# -> 2356     path = line.get_path()
#    2357     if path.vertices.size == 0:
#    2358         return
#
# File ~/Documents/lisaenv/lib/python3.9/site-packages/matplotlib/lines.py:1031, in Line2D.get_path(self)
#    1029 """Return the `~matplotlib.path.Path` associated with this line."""
#    1030 if self._invalidy or self._invalidx:
# -> 1031     self.recache()
#    1032 return self._path
#
# File ~/Documents/lisaenv/lib/python3.9/site-packages/matplotlib/lines.py:664, in Line2D.recache(self, always)
#     662 if always or self._invalidy:
#     663     yconv = self.convert_yunits(self._yorig)
# --> 664     y = _to_unmasked_float_array(yconv).ravel()
#     665 else:
#     666     y = self._y
#
# File ~/Documents/lisaenv/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:1369, in _to_unmasked_float_array(x)
#    1367     return np.ma.asarray(x, float).filled(np.nan)
#    1368 else:
# -> 1369     return np.asarray(x, float)
#
# TypeError: float() argument must be a string or a number, not 'function'
